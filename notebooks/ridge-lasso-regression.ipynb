# %% [markdown]
# ### DATA CLEANING

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('algerian_forest_fires_synthetic.csv')

# %%
dataset.head()
# Out:
#    region  day  month  year  temperature    rh   ws  rain  ffmc    dmc     dc  \
# 0  Bejaia   13      9  2012         36.3  58.2  5.9   2.1  76.2  131.8  714.2
# 1  Bejaia   24      8  2012         33.4  84.0  1.6   0.4  41.1  250.0  624.1
# 2  Bejaia   20      7  2012         37.6  19.5  6.8   0.7  92.9  157.0  335.8
# 3  Bejaia    3      6  2012         22.4  59.4  6.5   3.1  92.8  204.9  292.1
# 4  Bejaia    4      8  2012         35.4  26.8  2.2   1.6  60.4  171.5  354.8
#
#     isi    bui   fwi   classes
# 0  19.3  134.8  39.6      fire
# 1  17.4  342.5  40.0      fire
# 2   5.3  271.2  22.8      fire
# 3   8.7  244.5   3.0  not fire
# 4  19.8   36.6  10.4  not fire

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   region       250 non-null    object
#  1   day          250 non-null    int64
#  2   month        250 non-null    int64
#  3   year         250 non-null    int64
#  4   temperature  250 non-null    float64
#  5   rh           250 non-null    float64
#  6   ws           250 non-null    float64
#  7   rain         250 non-null    float64
#  8   ffmc         250 non-null    float64
#  9   dmc          250 non-null    float64
#  10  dc           250 non-null    float64
#  11  isi          250 non-null    float64
#  12  bui          250 non-null    float64
#  13  fwi          250 non-null    float64
#  14  classes      250 non-null    object
# dtypes: float64(10), int64(3), object(2)
# memory usage: 29.4+ KB

# %%
dataset[['day','month','year','temperature','rh','ffmc','rain','dmc','ws','dc','isi','bui','fwi']] = dataset[['day','month','year','temperature','rh','ffmc','rain','dmc','ws','dc','isi','bui','fwi']].astype('object')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   region       250 non-null    object
#  1   day          250 non-null    object
#  2   month        250 non-null    object
#  3   year         250 non-null    object
#  4   temperature  250 non-null    object
#  5   rh           250 non-null    object
#  6   ws           250 non-null    object
#  7   rain         250 non-null    object
#  8   ffmc         250 non-null    object
#  9   dmc          250 non-null    object
#  10  dc           250 non-null    object
#  11  isi          250 non-null    object
#  12  bui          250 non-null    object
#  13  fwi          250 non-null    object
#  14  classes      250 non-null    object
# dtypes: object(15)
# memory usage: 29.4+ KB

# %%
dataset.isnull().sum()
# Out:
# region         0
# day            0
# month          0
# year           0
# temperature    0
# rh             0
# ws             0
# rain           0
# ffmc           0
# dmc            0
# dc             0
# isi            0
# bui            0
# fwi            0
# classes        0
# dtype: int64

# %%
dataset.loc[:126,'region'] = 0
dataset.loc[127:,'region'] = 1

# %%
dataset.head()
# Out:
#   region   day month    year temperature    rh   ws rain  ffmc    dmc     dc  \
# 0      0  13.0   9.0  2012.0        36.3  58.2  5.9  2.1  76.2  131.8  714.2
# 1      0  24.0   8.0  2012.0        33.4  84.0  1.6  0.4  41.1  250.0  624.1
# 2      0  20.0   7.0  2012.0        37.6  19.5  6.8  0.7  92.9  157.0  335.8
# 3      0   3.0   6.0  2012.0        22.4  59.4  6.5  3.1  92.8  204.9  292.1
# 4      0   4.0   8.0  2012.0        35.4  26.8  2.2  1.6  60.4  171.5  354.8
#
#     isi    bui   fwi   classes
# 0  19.3  134.8  39.6      fire
# 1  17.4  342.5  40.0      fire
# 2   5.3  271.2  22.8      fire
# 3   8.7  244.5   3.0  not fire
# 4  19.8   36.6  10.4  not fire

# %%
dataset.tail()
# Out:
#     region   day month    year temperature    rh    ws rain  ffmc    dmc  \
# 245      1  26.0   9.0  2012.0        32.1  51.7  10.0  3.2  72.7  248.7
# 246      1   3.0   6.0  2012.0        24.4  24.4   9.7  3.1  54.2  270.0
# 247      1  10.0   9.0  2012.0        37.0  84.5   2.0  2.6  47.4  231.8
# 248      1   6.0   7.0  2012.0        34.8  57.8   9.6  4.3  74.2   41.9
# 249      1   2.0   7.0  2012.0        32.8  25.9   6.4  1.7  53.3  153.6
#
#         dc   isi    bui   fwi   classes
# 245  127.6  17.2   93.7  14.6  not fire
# 246  284.2   3.1  343.1   5.8  not fire
# 247  169.0   4.5  349.5  42.3      fire
# 248  299.4  19.2   43.4   5.0  not fire
# 249  238.3   4.4  308.0   7.8  not fire

# %%
dataset.isnull().sum()
# Out:
# region         0
# day            0
# month          0
# year           0
# temperature    0
# rh             0
# ws             0
# rain           0
# ffmc           0
# dmc            0
# dc             0
# isi            0
# bui            0
# fwi            0
# classes        0
# dtype: int64

# %%
# Remove duplicates if any
# dataset = dataset.drop_duplicates()

# Remove a particular row
# dataset = dataset.drop(150).reset_index(drop=True)

# %%
dataset.columns
# Out:
# Index(['region', 'day', 'month', 'year', 'temperature', 'rh', 'ws', 'rain',
#        'ffmc', 'dmc', 'dc', 'isi', 'bui', 'fwi', 'classes'],
#       dtype='object')

# %%
# Fix spaces in column names
# dataset.columns = dataset.columns.str.strip()
# df.columns

# %%
dataset[['day','month','year','temperature','rh','ws']] = dataset[['day','month','year','temperature','rh','ws']].astype('int')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   region       250 non-null    object
#  1   day          250 non-null    int32
#  2   month        250 non-null    int32
#  3   year         250 non-null    int32
#  4   temperature  250 non-null    int32
#  5   rh           250 non-null    int32
#  6   ws           250 non-null    int32
#  7   rain         250 non-null    object
#  8   ffmc         250 non-null    object
#  9   dmc          250 non-null    object
#  10  dc           250 non-null    object
#  11  isi          250 non-null    object
#  12  bui          250 non-null    object
#  13  fwi          250 non-null    object
#  14  classes      250 non-null    object
# dtypes: int32(6), object(9)
# memory usage: 23.6+ KB

# %%
objects = [features for features in dataset.columns if dataset[features].dtypes == 'object']

# %%
for i in objects:
    if i != 'classes':
        dataset[i] = dataset[i].astype('float')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   region       250 non-null    float64
#  1   day          250 non-null    int32
#  2   month        250 non-null    int32
#  3   year         250 non-null    int32
#  4   temperature  250 non-null    int32
#  5   rh           250 non-null    int32
#  6   ws           250 non-null    int32
#  7   rain         250 non-null    float64
#  8   ffmc         250 non-null    float64
#  9   dmc          250 non-null    float64
#  10  dc           250 non-null    float64
#  11  isi          250 non-null    float64
#  12  bui          250 non-null    float64
#  13  fwi          250 non-null    float64
#  14  classes      250 non-null    object
# dtypes: float64(8), int32(6), object(1)
# memory usage: 23.6+ KB

# %%
dataset['region'] = dataset['region'].astype('int')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   region       250 non-null    int32
#  1   day          250 non-null    int32
#  2   month        250 non-null    int32
#  3   year         250 non-null    int32
#  4   temperature  250 non-null    int32
#  5   rh           250 non-null    int32
#  6   ws           250 non-null    int32
#  7   rain         250 non-null    float64
#  8   ffmc         250 non-null    float64
#  9   dmc          250 non-null    float64
#  10  dc           250 non-null    float64
#  11  isi          250 non-null    float64
#  12  bui          250 non-null    float64
#  13  fwi          250 non-null    float64
#  14  classes      250 non-null    object
# dtypes: float64(7), int32(7), object(1)
# memory usage: 22.6+ KB

# %%
dataset.describe()
# Out:
#            region         day       month    year  temperature         rh  \
# count  250.000000  250.000000  250.000000   250.0   250.000000  250.00000
# mean     0.492000   13.992000    7.580000  2012.0    31.432000   50.43200
# std      0.500939    7.955697    1.110194     0.0     5.787864   23.29653
# min      0.000000    1.000000    6.000000  2012.0    22.000000   10.00000
# 25%      0.000000    7.000000    7.000000  2012.0    26.000000   31.00000
# 50%      0.000000   13.500000    8.000000  2012.0    32.000000   49.50000
# 75%      1.000000   20.000000    9.000000  2012.0    36.000000   71.75000
# max      1.000000   28.000000    9.000000  2012.0    42.000000   89.00000
#
#                ws       rain        ffmc        dmc         dc         isi  \
# count  250.000000  250.00000  250.000000  250.00000  250.00000  250.000000
# mean     4.756000    2.51240   69.234400  150.68040  409.23880   10.140000
# std      2.637478    1.47042   16.230098   85.79901  226.65061    5.832419
# ...

# %%
dataset.to_csv('algerian_forest_fires_synthetic_cleaned.csv', index=False)

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
dataset_copy = dataset.drop(['day','month','year'], axis=1)

# %%
dataset_copy.head()
# Out:
#    region  temperature  rh  ws  rain  ffmc    dmc     dc   isi    bui   fwi  \
# 0       0           36  58   5   2.1  76.2  131.8  714.2  19.3  134.8  39.6
# 1       0           33  84   1   0.4  41.1  250.0  624.1  17.4  342.5  40.0
# 2       0           37  19   6   0.7  92.9  157.0  335.8   5.3  271.2  22.8
# 3       0           22  59   6   3.1  92.8  204.9  292.1   8.7  244.5   3.0
# 4       0           35  26   2   1.6  60.4  171.5  354.8  19.8   36.6  10.4
#
#     classes
# 0      fire
# 1      fire
# 2      fire
# 3  not fire
# 4  not fire

# %%
dataset_copy['classes'].value_counts()
# Out:
# classes
# fire        170
# not fire     80
# Name: count, dtype: int64

# %%
plt.style.use('seaborn')
dataset_copy.hist(bins=50, figsize=(20,15))
plt.show()
# Out:
# C:\Users\sreek\AppData\Local\Temp\ipykernel_11884\1876977326.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
percentage = dataset_copy['classes'].value_counts(normalize=True)*100

# %%
classlabels = ['not fire', 'fire']
plt.figure(figsize=(10,7))
plt.pie(percentage, labels=classlabels, autopct='%1.1f%%', startangle=90, colors=['lightgreen','orange'], explode=(0.05,0.05), shadow=True)
plt.title('Distribution of Forest Fire Classes', fontsize=24, weight='bold')
plt.show()

# %%
sns.boxplot(dataset['fwi'])
# Out:
# <Axes: >

# %%
# Monthly fire analysis for bejaia region
df_temp = dataset.loc[dataset['region']==0]
plt.subplots(figsize=(12,6))
sns.set_style('whitegrid')
sns.countplot(x='month', hue='classes', data=df_temp)
plt.xlabel('Months', fontsize=14, weight='bold')
plt.ylabel('Number of Fires', fontsize=14, weight='bold')
plt.title('Monthly Forest Fire Analysis for Bejaia Region', fontsize=18, weight='bold')
plt.legend(title='Classes', labels=['Not Fire', 'Fire'])
plt.show()

# %%
# Monthly fire analysis for sedi-bel-abbes region
df_temp = dataset.loc[dataset['region']==1]
plt.subplots(figsize=(12,6))
sns.set_style('whitegrid')
sns.countplot(x='month', hue='classes', data=df_temp)
plt.xlabel('Months', fontsize=14, weight='bold')
plt.ylabel('Number of Fires', fontsize=14, weight='bold')
plt.title('Monthly Forest Fire Analysis for Sedi-Bel-Abbes Region', fontsize=18, weight='bold')
plt.legend(title='Classes', labels=['Not Fire', 'Fire'])
plt.show()

# %%
dataset['classes'] = np.where(dataset['classes'].str.contains("not fire"),0,1)

# %%
dataset['classes'].value_counts()
# Out:
# classes
# 1    170
# 0     80
# Name: count, dtype: int64

# %%
# Divide into independent and dependent features
X = dataset.drop('fwi',axis=1)
y = dataset['fwi']

# %%
X.head()
# Out:
#    region  temperature  rh  ws  rain  ffmc    dmc     dc   isi    bui   fwi  \
# 0       0           36  58   5   2.1  76.2  131.8  714.2  19.3  134.8  39.6
# 1       0           33  84   1   0.4  41.1  250.0  624.1  17.4  342.5  40.0
# 2       0           37  19   6   0.7  92.9  157.0  335.8   5.3  271.2  22.8
# 3       0           22  59   6   3.1  92.8  204.9  292.1   8.7  244.5   3.0
# 4       0           35  26   2   1.6  60.4  171.5  354.8  19.8   36.6  10.4
#
#    classes
# 0        1
# 1        1
# 2        1
# 3        0
# 4        0

# %%
y.head()
# Out:
# 0    39.6
# 1    40.0
# 2    22.8
# 3     3.0
# 4    10.4
# Name: fwi, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train.corr()
# Out:
#                region  temperature        rh        ws      rain      ffmc  \
# region       1.000000     0.045090 -0.047367  0.055737  0.074964 -0.030328
# temperature  0.045090     1.000000 -0.014099  0.059587 -0.061515  0.048059
# rh          -0.047367    -0.014099  1.000000 -0.076305 -0.000963  0.005401
# ws           0.055737     0.059587 -0.076305  1.000000 -0.003683  0.060110
# rain         0.074964    -0.061515 -0.000963 -0.003683  1.000000 -0.028587
# ffmc        -0.030328     0.048059  0.005401  0.060110 -0.028587  1.000000
# dmc         -0.027473    -0.018621 -0.059487 -0.080107  0.137057  0.031364
# dc          -0.055322     0.027799 -0.032083 -0.026964  0.009026 -0.049091
# isi          0.113502     0.030204  0.082029  0.031580  0.050047  0.022799
# bui         -0.021357     0.087056 -0.005796  0.169433 -0.001851 -0.118377
# fwi         -0.079676     0.074828  0.016592  0.015334 -0.092634  0.011491
# ...

# %%
plt.figure(figsize=(12,10))
corr = X_train.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
# Process Multi collinearity(Remove features that are nearly perfectly correlated i.e., threshold) if any
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
# Check the correlated features that are correlated above the 0.8185 threshold ***(WE CURRENTLY DONT HAVE ANY)***
# corr_features = correlation(X_train, 0.8185)
# corr_features

# %%
# Drop those features that are highly correlated
# X_train = X_train.drop(corr_features, axis=1,inplace=True)
# X_test = X_test.drop(corr_features, axis=1,inplace=True)
# X_train.shape , X_test.shape

# %% [markdown]
# ### Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.96324195, -1.62523037, -0.57552033, ...,  1.00342656,
#         -1.15146898, -1.37000842],
#        [-0.96324195,  0.11045255,  0.50502487, ...,  1.49289634,
#          1.53886836,  0.72992252],
#        [ 1.03816077,  0.11045255,  1.71523549, ...,  0.80530784,
#         -1.22312445, -1.37000842],
#        ...,
#        [-0.96324195,  0.97829401, -0.92129479, ..., -1.1263497 ,
#          1.63658037,  0.72992252],
#        [ 1.03816077, -0.23668403,  1.49912645, ..., -1.14868661,
#          1.12196378,  0.72992252],
#        [-0.96324195, -1.62523037, -1.05096022, ..., -0.63785109,
#          0.9721387 ,  0.72992252]])

# %% [markdown]
# ### Box plot to understand standard scaler

# %%
plt.subplots(figsize=(12,10))
plt.subplot(1,2,1)
sns.boxplot(data=X_train)
plt.title('Before Scaling')
plt.subplot(1,2,2)
sns.boxplot(data=X_train_scaled)
plt.title('After Scaling')
plt.show()
# Out:
# C:\Users\sreek\AppData\Local\Temp\ipykernel_11884\1243492785.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,1)

# %% [markdown]
# # Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score
regressor = LinearRegression()
regressor.fit(X_train_scaled, y_train)
y_pred = regressor.predict(X_test_scaled)
mae = mean_absolute_error(y_test, y_pred)
r2_score = r2_score(y_test, y_pred)
print("Mean Absolute Error:", mae)
print("R2 Score:", r2_score)
plt.scatter(y_test, y_pred)
# Out:
# Mean Absolute Error: 1.0651092001324518e-14
# R2 Score: 1.0

# %% [markdown]
# ## Lasso Regression

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error, r2_score
lasso = Lasso()
lasso.fit(X_train_scaled, y_train)
y_pred = lasso.predict(X_test_scaled)
mae = mean_absolute_error(y_test, y_pred)
score = r2_score(y_test, y_pred)
print("Mean Absolute Error:", mae)
print("R2 Score:", score)
plt.scatter(y_test, y_pred)
# Out:
# Mean Absolute Error: 0.8404327642948913
# R2 Score: 0.995458941071444

# %% [markdown]
# #### Cross Validation and Hyperparameter Tuning

# %%
from sklearn.linear_model import LassoCV
lassocv = LassoCV()
lassocv.fit(X_train_scaled, y_train)
# Out:
# LassoCV()

# %%
lassocv.alpha_
# Out:
# 0.015351234769021902

# %%
lassocv.alphas_
# Out:
# array([15.35123477, 14.31661292, 13.35172113, 12.45185981, 11.61264614,
#        10.82999265, 10.10008739,  9.41937531,  8.78454094,  8.19249228,
#         7.64034572,  7.12541199,  6.64518307,  6.19731997,  5.77964135,
#         5.39011286,  5.0268373 ,  4.68804529,  4.37208672,  4.07742271,
#         3.80261807,  3.54633434,  3.30732327,  3.08442075,  2.87654112,
#         2.68267187,  2.50186877,  2.33325119,  2.17599787,  2.02934289,
#         1.89257197,  1.76501896,  1.64606259,  1.53512348,  1.43166129,
#         1.33517211,  1.24518598,  1.16126461,  1.08299927,  1.01000874,
#         0.94193753,  0.87845409,  0.81924923,  0.76403457,  0.7125412 ,
#         0.66451831,  0.619732  ,  0.57796413,  0.53901129,  0.50268373,
#         0.46880453,  0.43720867,  0.40774227,  0.38026181,  0.35463343,
#         0.33073233,  0.30844208,  0.28765411,  0.26826719,  0.25018688,
#         0.23332512,  0.21759979,  0.20293429,  0.1892572 ,  0.1765019 ,
# ...

# %%
lassocv.mse_path_
# Out:
# array([[2.45511154e+02, 2.60120237e+02, 2.39386966e+02, 2.30634697e+02,
#         1.96022132e+02],
#        [2.18056787e+02, 2.38356682e+02, 2.08970982e+02, 2.00594298e+02,
#         1.70490054e+02],
#        [1.89654673e+02, 2.07310487e+02, 1.81752303e+02, 1.74466690e+02,
#         1.48283555e+02],
#        [1.64951963e+02, 1.80308089e+02, 1.58078885e+02, 1.51742230e+02,
#         1.28969474e+02],
#        [1.43466805e+02, 1.56822781e+02, 1.37488952e+02, 1.31977653e+02,
#         1.12171071e+02],
#        [1.24780111e+02, 1.36396457e+02, 1.19580879e+02, 1.14787432e+02,
#         9.75606772e+01],
#        [1.08527377e+02, 1.18630683e+02, 1.04005350e+02, 9.98362547e+01,
#         8.48533017e+01],
#        [9.43915776e+01, 1.03178918e+02, 9.04585497e+01, 8.68324829e+01,
#         7.38010745e+01],
#        [8.20969805e+01, 8.97397609e+01, 7.86762334e+01, 7.55224654e+01,
#         6.41884109e+01],
#        [7.14037669e+01, 7.80510675e+01, 6.84285755e+01, 6.56855890e+01,
# ...

# %% [markdown]
# #### Ridge Model Regression

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error, r2_score
ridge = Ridge()
ridge.fit(X_train_scaled, y_train)
y_pred = ridge.predict(X_test_scaled)
mae = mean_absolute_error(y_test, y_pred)
score = r2_score(y_test, y_pred)
print("Mean Absolute Error:", mae)
print("R2 Score:", score)
plt.scatter(y_test, y_pred)
# Out:
# Mean Absolute Error: 0.126883682179255
# R2 Score: 0.9998908839884136

# %% [markdown]
# #### Cross Validation for Ridge Regression ####

# %%
from sklearn.linear_model import RidgeCV
ridgecv = RidgeCV()
ridgecv.fit(X_train_scaled, y_train)
# Out:
# RidgeCV()

# %%
ridgecv.alpha_
# Out:
# 0.1

# %%
ridgecv.get_params()
# Out:
# {'alpha_per_target': False,
#  'alphas': (0.1, 1.0, 10.0),
#  'cv': None,
#  'fit_intercept': True,
#  'gcv_mode': None,
#  'scoring': None,
#  'store_cv_values': False}

# %% [markdown]
# # ElasticNet Regression

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error, r2_score
elasticnet = ElasticNet()
elasticnet.fit(X_train_scaled, y_train)
y_pred = elasticnet.predict(X_test_scaled)
mae = mean_absolute_error(y_test, y_pred)
score = r2_score(y_test, y_pred)
print("Mean Absolute Error:", mae)
print("R2 Score:", score)
plt.scatter(y_test, y_pred)
# Out:
# Mean Absolute Error: 4.21825435972235
# R2 Score: 0.8798291836134394

# %%
from sklearn.linear_model import ElasticNetCV
elasticnetcv = ElasticNetCV()
elasticnetcv.fit(X_train_scaled, y_train)
# Out:
# ElasticNetCV()

# %%
elasticnetcv.alpha_
# Out:
# 0.030702469538043804

# %%
elasticnetcv.alphas_
# Out:
# array([30.70246954, 28.63322585, 26.70344226, 24.90371962, 23.22529227,
#        21.6599853 , 20.20017479, 18.83875062, 17.56908187, 16.38498456,
#        15.28069144, 14.25082398, 13.29036614, 12.39463994, 11.55928269,
#        10.78022573, 10.05367459,  9.37609057,  8.74417345,  8.15484542,
#         7.60523614,  7.09266867,  6.61464654,  6.16884151,  5.75308223,
#         5.36534375,  5.00373754,  4.66650237,  4.35199573,  4.05868578,
#         3.78514395,  3.53003791,  3.29212517,  3.07024695,  2.86332258,
#         2.67034423,  2.49037196,  2.32252923,  2.16599853,  2.02001748,
#         1.88387506,  1.75690819,  1.63849846,  1.52806914,  1.4250824 ,
#         1.32903661,  1.23946399,  1.15592827,  1.07802257,  1.00536746,
#         0.93760906,  0.87441734,  0.81548454,  0.76052361,  0.70926687,
#         0.66146465,  0.61688415,  0.57530822,  0.53653437,  0.50037375,
#         0.46665024,  0.43519957,  0.40586858,  0.37851439,  0.35300379,
# ...

# %%
import pickle
pickle.dump(scaler,open('scaler.pkl','wb'))
pickle.dump(ridge,open('ridge.pkl','wb'))
